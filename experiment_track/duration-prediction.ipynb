# %%
# !python -V
# Out:
# Python 3.7.13

# %%
import pandas as pd

# %%
import pickle

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
from sklearn.feature_extraction import DictVectorizer
from sklearn.linear_model import LinearRegression
from sklearn.linear_model import Lasso
from sklearn.linear_model import Ridge

from sklearn.metrics import mean_squared_error

# %%
import mlflow


mlflow.set_tracking_uri("sqlite:///mlflow.db")
mlflow.set_experiment("nyc-taxi-experiment2")
# Out:
# <Experiment: artifact_location='./mlruns/2', creation_time=1685499389635, experiment_id='2', last_update_time=1685499389635, lifecycle_stage='active', name='nyc-taxi-experiment2', tags={}>

# %%
def read_dataframe(filename, type):
    if type == "parquet":
        df = pd.read_parquet(filename)
    else:
        df = pd.read_csv(filename)
        df.lpep_dropoff_datetime = pd.to_datetime(df.lpep_dropoff_datetime)
        df.lpep_pickup_datetime = pd.to_datetime(df.lpep_pickup_datetime)

    df['duration'] = df.lpep_dropoff_datetime - df.lpep_pickup_datetime
    df.duration = df.duration.astype('timedelta64[s]') / 60

    df = df[(df.duration >= 1) & (df.duration <= 60)]

    categorical = ['PULocationID', 'DOLocationID']
    df[categorical] = df[categorical].astype(str)
    
    return df

# %%
df_train = read_dataframe(
    './data/green_tripdata_2021-01.parquet',
    'parquet')
df_val = read_dataframe(
    './data/green_tripdata_2021-02.parquet',
    'parquet')

# %%
len(df_train), len(df_val)
# Out:
# (73908, 61921)

# %%
df_train['PU_DO'] = df_train['PULocationID'] + '_' + df_train['DOLocationID']
df_val['PU_DO'] = df_val['PULocationID'] + '_' + df_val['DOLocationID']

# %%
categorical = ['PU_DO'] #'PULocationID', 'DOLocationID']
numerical = ['trip_distance']

dv = DictVectorizer()

train_dicts = df_train[categorical + numerical].to_dict(orient='records')
X_train = dv.fit_transform(train_dicts)

val_dicts = df_val[categorical + numerical].to_dict(orient='records')
X_val = dv.transform(val_dicts)

# %%
target = 'duration'
y_train = df_train[target].values
y_val = df_val[target].values

# %%
lr = LinearRegression()
lr.fit(X_train, y_train)

y_pred = lr.predict(X_val)

mean_squared_error(y_val, y_pred, squared=False)
# Out:
# 7.479340440870557

# %%
with open('models/lin_reg.bin', 'wb') as f_out:
    pickle.dump((dv, lr), f_out)

# %%
with mlflow.start_run():

    mlflow.set_tag("developer", "luis")

    mlflow.log_param(
        "train-data-path",
          "./data/green_tripdata_2021-01.parquet"
    )
    mlflow.log_param(
        "valid-data-path", 
        "./data/green_tripdata_2021-02.parquet"
    )

    alpha = 1
    mlflow.log_param("alpha", alpha)
    lr = Lasso(alpha)
    lr.fit(X_train, y_train)

    y_pred = lr.predict(X_val)
    rmse = mean_squared_error(y_val, y_pred, squared=False)
    mlflow.log_metric("rmse", rmse)

    mlflow.log_artifact(
        local_path="models/lin_reg.bin", 
        artifact_path="models_pickle"
    )

# %%
import xgboost as xgb

# %%
from hyperopt import fmin, tpe, hp, STATUS_OK, Trials
from hyperopt.pyll import scope

# %%
train = xgb.DMatrix(X_train, label=y_train)
valid = xgb.DMatrix(X_val, label=y_val)

# %%
def objective(params):
    with mlflow.start_run():
        mlflow.set_tag("model", "xgboost")
        mlflow.log_params(params)
        booster = xgb.train(
            params=params,
            dtrain=train,
            num_boost_round=100,
            evals=[(valid, 'validation')],
            early_stopping_rounds=15
        )
        y_pred = booster.predict(valid)
        rmse = mean_squared_error(y_val, y_pred, squared=False)
        mlflow.log_metric("rmse", rmse)

    return {'loss': rmse, 'status': STATUS_OK}

# %%
search_space = {
    'max_depth': scope.int(hp.quniform('max_depth', 4, 100, 1)),
    'learning_rate': hp.loguniform('learning_rate', -3, 0),
    'reg_alpha': hp.loguniform('reg_alpha', -5, -1),
    'reg_lambda': hp.loguniform('reg_lambda', -6, -1),
    'min_child_weight': hp.loguniform('min_child_weight', -1, 3),
    'objective': 'reg:squarederror',
    'seed': 42,
    #'tree_method': 'gpu_hist'
}

best_result = fmin(
    fn=objective,
    space=search_space,
    algo=tpe.suggest,
    max_evals=10,
    trials=Trials()
)
# Out:
# [0]	validation-rmse:12.73379
# [1]	validation-rmse:9.01004
# [2]	validation-rmse:7.52473
# [3]	validation-rmse:6.95479
# [4]	validation-rmse:6.72402
# [5]	validation-rmse:6.61989
# [6]	validation-rmse:6.57003
# [7]	validation-rmse:6.54286
# [8]	validation-rmse:6.52949
# [9]	validation-rmse:6.52249
# [10]	validation-rmse:6.51419
# [11]	validation-rmse:6.50994
# [12]	validation-rmse:6.50549
# [13]	validation-rmse:6.50170
# [14]	validation-rmse:6.49578
# [15]	validation-rmse:6.49397
# [16]	validation-rmse:6.49048
# [17]	validation-rmse:6.48785
# [18]	validation-rmse:6.48535
# [19]	validation-rmse:6.48306
# [20]	validation-rmse:6.48035
# [21]	validation-rmse:6.47884
# [22]	validation-rmse:6.47674
# [23]	validation-rmse:6.47642
# [24]	validation-rmse:6.47561
# [25]	validation-rmse:6.47382
# [26]	validation-rmse:6.47149
# [27]	validation-rmse:6.47003
# [28]	validation-rmse:6.46911
# [29]	validation-rmse:6.46647
# [30]	validation-rmse:6.46553
# [31]	validation-rmse:6.46493
# [32]	validation-rmse:6.46456
# [33]	validation-rmse:6.46441
# [34]	validation-rmse:6.46397
# [35]	validation-rmse:6.46353
# [36]	validation-rmse:6.46209
# [37]	validation-rmse:6.46140
# [38]	validation-rmse:6.46032
# [39]	validation-rmse:6.45908
# [40]	validation-rmse:6.45771
# [41]	validation-rmse:6.45855
# [42]	validation-rmse:6.45857
# [43]	validation-rmse:6.45866
# [44]	validation-rmse:6.45907
# [45]	validation-rmse:6.45794
# [46]	validation-rmse:6.45771
# [47]	validation-rmse:6.45754
# [48]	validation-rmse:6.45639
# [49]	validation-rmse:6.45445
# [50]	validation-rmse:6.45493
# [51]	validation-rmse:6.45481
# [52]	validation-rmse:6.45542
# [53]	validation-rmse:6.45535
# [54]	validation-rmse:6.45562
# [55]	validation-rmse:6.45505
# [56]	validation-rmse:6.45344
# [57]	validation-rmse:6.45441
# [58]	validation-rmse:6.45383
# [59]	validation-rmse:6.45285
# [60]	validation-rmse:6.45251
# [61]	validation-rmse:6.45392
# [62]	validation-rmse:6.45444
# [63]	validation-rmse:6.45484
# [64]	validation-rmse:6.45516
# [65]	validation-rmse:6.45632
# [66]	validation-rmse:6.45660
# [67]	validation-rmse:6.45709
# [68]	validation-rmse:6.45703
# [69]	validation-rmse:6.45773
# [70]	validation-rmse:6.45766
# [71]	validation-rmse:6.45794
# [72]	validation-rmse:6.46393
# [73]	validation-rmse:6.46457
# [74]	validation-rmse:6.47167
# [75]	validation-rmse:6.47164
# [0]	validation-rmse:18.27815
# [1]	validation-rmse:15.90080
# [2]	validation-rmse:13.96374
# [3]	validation-rmse:12.40385
# [4]	validation-rmse:11.14387
# [5]	validation-rmse:10.14382
# [6]	validation-rmse:9.35996
# [7]	validation-rmse:8.74485
# [8]	validation-rmse:8.26014
# [9]	validation-rmse:7.89192
# [10]	validation-rmse:7.60542
# [11]	validation-rmse:7.38687
# [12]	validation-rmse:7.21107
# [13]	validation-rmse:7.07727
# [14]	validation-rmse:6.97272
# [15]	validation-rmse:6.88950
# [16]	validation-rmse:6.82131
# [17]	validation-rmse:6.76860
# [18]	validation-rmse:6.72640
# [19]	validation-rmse:6.69045
# [20]	validation-rmse:6.66199
# [21]	validation-rmse:6.64120
# [22]	validation-rmse:6.62568
# [23]	validation-rmse:6.61228
# [24]	validation-rmse:6.59843
# [25]	validation-rmse:6.58805
# [26]	validation-rmse:6.57876
# [27]	validation-rmse:6.56996
# [28]	validation-rmse:6.56391
# [29]	validation-rmse:6.55909
# [30]	validation-rmse:6.55449
# [31]	validation-rmse:6.55020
# [32]	validation-rmse:6.54686
# [33]	validation-rmse:6.54402
# [34]	validation-rmse:6.53994
# [35]	validation-rmse:6.53773
# [36]	validation-rmse:6.53479
# [37]	validation-rmse:6.53200
# [38]	validation-rmse:6.52919
# [39]	validation-rmse:6.52787
# [40]	validation-rmse:6.52508
# [41]	validation-rmse:6.52365
# [42]	validation-rmse:6.52271
# [43]	validation-rmse:6.52147
# [44]	validation-rmse:6.52035
# [45]	validation-rmse:6.51857
# [46]	validation-rmse:6.51726
# [47]	validation-rmse:6.51618
# [48]	validation-rmse:6.51595
# [49]	validation-rmse:6.51514
# [50]	validation-rmse:6.51446
# [51]	validation-rmse:6.51396
# [52]	validation-rmse:6.51247
# [53]	validation-rmse:6.51155
# [54]	validation-rmse:6.51061
# [55]	validation-rmse:6.51026
# [56]	validation-rmse:6.50894
# [57]	validation-rmse:6.50760
# [58]	validation-rmse:6.50652
# [59]	validation-rmse:6.50568
# [60]	validation-rmse:6.50409
# [61]	validation-rmse:6.50360
# [62]	validation-rmse:6.50206
# [63]	validation-rmse:6.50172
# [64]	validation-rmse:6.50069
# [65]	validation-rmse:6.50013
# [66]	validation-rmse:6.49950
# [67]	validation-rmse:6.49901
# [68]	validation-rmse:6.49840
# [69]	validation-rmse:6.49786
# [70]	validation-rmse:6.49716
# [71]	validation-rmse:6.49696
# [72]	validation-rmse:6.49743
# [73]	validation-rmse:6.49642
# [74]	validation-rmse:6.49593
# [75]	validation-rmse:6.49537
# [76]	validation-rmse:6.49480
# [77]	validation-rmse:6.49426
# [78]	validation-rmse:6.49389
# [79]	validation-rmse:6.49368
# [80]	validation-rmse:6.49319
# [81]	validation-rmse:6.49300
# [82]	validation-rmse:6.49211
# [83]	validation-rmse:6.49130
# [84]	validation-rmse:6.49069
# [85]	validation-rmse:6.49074
# [86]	validation-rmse:6.48989
# [87]	validation-rmse:6.48934
# [88]	validation-rmse:6.48913
# [89]	validation-rmse:6.48828
# [90]	validation-rmse:6.48825
# [91]	validation-rmse:6.48741
# [92]	validation-rmse:6.48672
# [93]	validation-rmse:6.48593
# [94]	validation-rmse:6.48541
# [95]	validation-rmse:6.48425
# [96]	validation-rmse:6.48346
# [97]	validation-rmse:6.48265
# [98]	validation-rmse:6.48209
# [99]	validation-rmse:6.48155
# [0]	validation-rmse:10.87899
# [1]	validation-rmse:7.76573
# [2]	validation-rmse:6.93624
# [3]	validation-rmse:6.69079
# [4]	validation-rmse:6.60928
# [5]	validation-rmse:6.57332
# [6]	validation-rmse:6.55475
# [7]	validation-rmse:6.54706
# [8]	validation-rmse:6.54106
# [9]	validation-rmse:6.53509
# [10]	validation-rmse:6.53108
# [11]	validation-rmse:6.52519
# [12]	validation-rmse:6.52258
# [13]	validation-rmse:6.51748
# [14]	validation-rmse:6.51519
# [15]	validation-rmse:6.51220
# [16]	validation-rmse:6.50507
# [17]	validation-rmse:6.50327
# [18]	validation-rmse:6.50120
# [19]	validation-rmse:6.49824
# [20]	validation-rmse:6.49403
# [21]	validation-rmse:6.49360
# [22]	validation-rmse:6.48863
# [23]	validation-rmse:6.48669
# [24]	validation-rmse:6.48477
# [25]	validation-rmse:6.47998
# [26]	validation-rmse:6.47664
# [27]	validation-rmse:6.47713
# [28]	validation-rmse:6.47743
# [29]	validation-rmse:6.47582
# [30]	validation-rmse:6.47430
# [31]	validation-rmse:6.47201
# [32]	validation-rmse:6.47194
# [33]	validation-rmse:6.46966
# [34]	validation-rmse:6.47221
# [35]	validation-rmse:6.46933
# [36]	validation-rmse:6.46562
# [37]	validation-rmse:6.46497
# [38]	validation-rmse:6.46380
# [39]	validation-rmse:6.46116
# [40]	validation-rmse:6.45949
# [41]	validation-rmse:6.45766
# [42]	validation-rmse:6.45653
# [43]	validation-rmse:6.45617
# [44]	validation-rmse:6.45469
# [45]	validation-rmse:6.45397
# [46]	validation-rmse:6.45305
# [47]	validation-rmse:6.45224
# [48]	validation-rmse:6.45075
# [49]	validation-rmse:6.44995
# [50]	validation-rmse:6.44944
# [51]	validation-rmse:6.44588
# [52]	validation-rmse:6.44414
# [53]	validation-rmse:6.44462
# [54]	validation-rmse:6.44373
# [55]	validation-rmse:6.44482
# [56]	validation-rmse:6.44485
# [57]	validation-rmse:6.44342
# [58]	validation-rmse:6.44318
# [59]	validation-rmse:6.44177
# [60]	validation-rmse:6.44254
# [61]	validation-rmse:6.44294
# [62]	validation-rmse:6.44257
# [63]	validation-rmse:6.44404
# [64]	validation-rmse:6.44469
# [65]	validation-rmse:6.44664
# [66]	validation-rmse:6.45197
# [67]	validation-rmse:6.45558
# [68]	validation-rmse:6.45377
# [69]	validation-rmse:6.45318
# [70]	validation-rmse:6.45235
# [71]	validation-rmse:6.45328
# [72]	validation-rmse:6.45301
# [73]	validation-rmse:6.45241
# [74]	validation-rmse:6.45301
# [0]	validation-rmse:11.03766
# [1]	validation-rmse:7.83599
# [2]	validation-rmse:6.96828
# [3]	validation-rmse:6.71454
# [4]	validation-rmse:6.62822
# [5]	validation-rmse:6.59043
# [6]	validation-rmse:6.56450
# [7]	validation-rmse:6.55203
# [8]	validation-rmse:6.54435
# [9]	validation-rmse:6.53658
# [10]	validation-rmse:6.53354
# [11]	validation-rmse:6.53254
# [12]	validation-rmse:6.52862
# [13]	validation-rmse:6.52579
# [14]	validation-rmse:6.52304
# [15]	validation-rmse:6.52193
# [16]	validation-rmse:6.51999
# [17]	validation-rmse:6.51948
# [18]	validation-rmse:6.51252
# [19]	validation-rmse:6.50999
# [20]	validation-rmse:6.50827
# [21]	validation-rmse:6.50567
# [22]	validation-rmse:6.50605
# [23]	validation-rmse:6.50493
# [24]	validation-rmse:6.50390
# [25]	validation-rmse:6.50465
# [26]	validation-rmse:6.50350
# [27]	validation-rmse:6.50237
# [28]	validation-rmse:6.50081
# [29]	validation-rmse:6.49885
# [30]	validation-rmse:6.49759
# [31]	validation-rmse:6.49618
# [32]	validation-rmse:6.49715
# [33]	validation-rmse:6.49678
# [34]	validation-rmse:6.49565
# [35]	validation-rmse:6.49582
# [36]	validation-rmse:6.49447
# [37]	validation-rmse:6.49327
# [38]	validation-rmse:6.49196
# [39]	validation-rmse:6.49271
# [40]	validation-rmse:6.49600
# [41]	validation-rmse:6.49614
# [42]	validation-rmse:6.49577
# [43]	validation-rmse:6.49530
# [44]	validation-rmse:6.49454
# [45]	validation-rmse:6.49415
# [46]	validation-rmse:6.49443
# [47]	validation-rmse:6.49328
# [48]	validation-rmse:6.49335
# [49]	validation-rmse:6.49311
# [50]	validation-rmse:6.49264
# [51]	validation-rmse:6.49316
# [52]	validation-rmse:6.49301
# [53]	validation-rmse:6.49311
# [0]	validation-rmse:19.59584
# [1]	validation-rmse:18.15584
# [2]	validation-rmse:16.85889
# [3]	validation-rmse:15.69206
# [4]	validation-rmse:14.64642
# [5]	validation-rmse:13.70866
# [6]	validation-rmse:12.87073
# [7]	validation-rmse:12.12167
# [8]	validation-rmse:11.45523
# [9]	validation-rmse:10.86270
# [10]	validation-rmse:10.33632
# [11]	validation-rmse:9.87061
# [12]	validation-rmse:9.46081
# [13]	validation-rmse:9.10118
# [14]	validation-rmse:8.78186
# [15]	validation-rmse:8.50298
# [16]	validation-rmse:8.25786
# [17]	validation-rmse:8.04439
# [18]	validation-rmse:7.85681
# [19]	validation-rmse:7.69433
# [20]	validation-rmse:7.55152
# [21]	validation-rmse:7.42581
# [22]	validation-rmse:7.31685
# [23]	validation-rmse:7.22171
# [24]	validation-rmse:7.13792
# [25]	validation-rmse:7.06514
# [26]	validation-rmse:7.00053
# [27]	validation-rmse:6.94342
# [28]	validation-rmse:6.89355
# [29]	validation-rmse:6.85039
# [30]	validation-rmse:6.81080
# [31]	validation-rmse:6.77525
# [32]	validation-rmse:6.74433
# [33]	validation-rmse:6.71699
# [34]	validation-rmse:6.69175
# [35]	validation-rmse:6.66947
# [36]	validation-rmse:6.64944
# [37]	validation-rmse:6.63183
# [38]	validation-rmse:6.61590
# [39]	validation-rmse:6.60146
# [40]	validation-rmse:6.58798
# [41]	validation-rmse:6.57697
# [42]	validation-rmse:6.56579
# [43]	validation-rmse:6.55584
# [44]	validation-rmse:6.54700
# [45]	validation-rmse:6.53821
# [46]	validation-rmse:6.53091
# [47]	validation-rmse:6.52416
# [48]	validation-rmse:6.51850
# [49]	validation-rmse:6.51357
# [50]	validation-rmse:6.50920
# [51]	validation-rmse:6.50525
# [52]	validation-rmse:6.50152
# [53]	validation-rmse:6.49744
# [54]	validation-rmse:6.49458
# [55]	validation-rmse:6.49175
# [56]	validation-rmse:6.48893
# [57]	validation-rmse:6.48634
# [58]	validation-rmse:6.48396
# [59]	validation-rmse:6.48208
# [60]	validation-rmse:6.47998
# [61]	validation-rmse:6.47838
# [62]	validation-rmse:6.47651
# [63]	validation-rmse:6.47503
# [64]	validation-rmse:6.47374
# [65]	validation-rmse:6.47241
# [66]	validation-rmse:6.47102
# [67]	validation-rmse:6.46982
# [68]	validation-rmse:6.46840
# [69]	validation-rmse:6.46742
# [70]	validation-rmse:6.46586
# [71]	validation-rmse:6.46479
# [72]	validation-rmse:6.46375
# [73]	validation-rmse:6.46247
# [74]	validation-rmse:6.46133
# [75]	validation-rmse:6.46024
# [76]	validation-rmse:6.45924
# [77]	validation-rmse:6.45831
# [78]	validation-rmse:6.45705
# [79]	validation-rmse:6.45630
# [80]	validation-rmse:6.45555
# [81]	validation-rmse:6.45427
# [82]	validation-rmse:6.45356
# [83]	validation-rmse:6.45269
# [84]	validation-rmse:6.45229
# [85]	validation-rmse:6.45135
# [86]	validation-rmse:6.45021
# [87]	validation-rmse:6.44918
# [88]	validation-rmse:6.44882
# [89]	validation-rmse:6.44806
# [90]	validation-rmse:6.44742
# [91]	validation-rmse:6.44650
# [92]	validation-rmse:6.44590
# [93]	validation-rmse:6.44514
# [94]	validation-rmse:6.44448
# [95]	validation-rmse:6.44389
# [96]	validation-rmse:6.44339
# [97]	validation-rmse:6.44309
# [98]	validation-rmse:6.44253
# [99]	validation-rmse:6.44206
# [0]	validation-rmse:15.85977
# [1]	validation-rmse:12.35412
# [2]	validation-rmse:10.10642
# [3]	validation-rmse:8.70222
# [4]	validation-rmse:7.85316
# [5]	validation-rmse:7.35340
# [6]	validation-rmse:7.04733
# [7]	validation-rmse:6.86134
# [8]	validation-rmse:6.74673
# [9]	validation-rmse:6.67129
# [10]	validation-rmse:6.62028
# [11]	validation-rmse:6.58848
# [12]	validation-rmse:6.56401
# [13]	validation-rmse:6.54677
# [14]	validation-rmse:6.53158
# [15]	validation-rmse:6.52029
# [16]	validation-rmse:6.51336
# [17]	validation-rmse:6.50810
# [18]	validation-rmse:6.50398
# [19]	validation-rmse:6.49968
# [20]	validation-rmse:6.49755
# [21]	validation-rmse:6.49511
# [22]	validation-rmse:6.49154
# [23]	validation-rmse:6.48938
# [24]	validation-rmse:6.48692
# [25]	validation-rmse:6.48556
# [26]	validation-rmse:6.48334
# [27]	validation-rmse:6.48069
# [28]	validation-rmse:6.47909
# [29]	validation-rmse:6.47768
# [30]	validation-rmse:6.47635
# [31]	validation-rmse:6.47487
# [32]	validation-rmse:6.47335
# [33]	validation-rmse:6.47169
# [34]	validation-rmse:6.46957
# [35]	validation-rmse:6.46707
# [36]	validation-rmse:6.46604
# [37]	validation-rmse:6.46505
# [38]	validation-rmse:6.46397
# [39]	validation-rmse:6.46250
# [40]	validation-rmse:6.46156
# [41]	validation-rmse:6.46139
# [42]	validation-rmse:6.45991
# [43]	validation-rmse:6.45847
# [44]	validation-rmse:6.45875
# [45]	validation-rmse:6.45788
# [46]	validation-rmse:6.45647
# [47]	validation-rmse:6.45624
# [48]	validation-rmse:6.45495
# [49]	validation-rmse:6.45409
# [50]	validation-rmse:6.45329
# [51]	validation-rmse:6.45315
# [52]	validation-rmse:6.45212
# [53]	validation-rmse:6.45134
# [54]	validation-rmse:6.45052
# [55]	validation-rmse:6.44930
# [56]	validation-rmse:6.44904
# [57]	validation-rmse:6.44909
# [58]	validation-rmse:6.44765
# [59]	validation-rmse:6.44703
# [60]	validation-rmse:6.44618
# [61]	validation-rmse:6.44516
# [62]	validation-rmse:6.44406
# [63]	validation-rmse:6.44305
# [64]	validation-rmse:6.44274
# [65]	validation-rmse:6.44198
# [66]	validation-rmse:6.44248
# [67]	validation-rmse:6.44217
# [68]	validation-rmse:6.44259
# [69]	validation-rmse:6.44167
# [70]	validation-rmse:6.44144
# [71]	validation-rmse:6.44178
# [72]	validation-rmse:6.44074
# [73]	validation-rmse:6.44000
# [74]	validation-rmse:6.43912
# [75]	validation-rmse:6.43974
# [76]	validation-rmse:6.43869
# [77]	validation-rmse:6.43805
# [78]	validation-rmse:6.43701
# [79]	validation-rmse:6.43630
# [80]	validation-rmse:6.43554
# [81]	validation-rmse:6.43486
# [82]	validation-rmse:6.43410
# [83]	validation-rmse:6.43365
# [84]	validation-rmse:6.43327
# [85]	validation-rmse:6.43227
# [86]	validation-rmse:6.43192
# [87]	validation-rmse:6.43120
# [88]	validation-rmse:6.43132
# [89]	validation-rmse:6.43050
# [90]	validation-rmse:6.43014
# [91]	validation-rmse:6.43066
# [92]	validation-rmse:6.43023
# [93]	validation-rmse:6.42971
# [94]	validation-rmse:6.42956
# [95]	validation-rmse:6.42912
# [96]	validation-rmse:6.42864
# [97]	validation-rmse:6.42853
# [98]	validation-rmse:6.42841
# [99]	validation-rmse:6.42804
# [0]	validation-rmse:19.34816
# [1]	validation-rmse:17.71408
# [2]	validation-rmse:16.26930
# [3]	validation-rmse:14.99346
# [4]	validation-rmse:13.86990
# [5]	validation-rmse:12.88357
# [6]	validation-rmse:12.02026
# [7]	validation-rmse:11.26432
# [8]	validation-rmse:10.60677
# [9]	validation-rmse:10.03746
# [10]	validation-rmse:9.54314
# [11]	validation-rmse:9.11851
# [12]	validation-rmse:8.75168
# [13]	validation-rmse:8.43699
# [14]	validation-rmse:8.16775
# [15]	validation-rmse:7.93669
# [16]	validation-rmse:7.73808
# [17]	validation-rmse:7.56774
# [18]	validation-rmse:7.42246
# [19]	validation-rmse:7.29977
# [20]	validation-rmse:7.19356
# [21]	validation-rmse:7.10121
# [22]	validation-rmse:7.02201
# [23]	validation-rmse:6.95375
# [24]	validation-rmse:6.89566
# [25]	validation-rmse:6.84546
# [26]	validation-rmse:6.80223
# [27]	validation-rmse:6.76384
# [28]	validation-rmse:6.73146
# [29]	validation-rmse:6.70247
# [30]	validation-rmse:6.67631
# [31]	validation-rmse:6.65365
# [32]	validation-rmse:6.63421
# [33]	validation-rmse:6.61671
# [34]	validation-rmse:6.60125
# [35]	validation-rmse:6.58684
# [36]	validation-rmse:6.57478
# [37]	validation-rmse:6.56389
# [38]	validation-rmse:6.55310
# [39]	validation-rmse:6.54467
# [40]	validation-rmse:6.53703
# [41]	validation-rmse:6.52998
# [42]	validation-rmse:6.52439
# [43]	validation-rmse:6.51923
# [44]	validation-rmse:6.51503
# [45]	validation-rmse:6.51132
# [46]	validation-rmse:6.50784
# [47]	validation-rmse:6.50449
# [48]	validation-rmse:6.50206
# [49]	validation-rmse:6.49920
# [50]	validation-rmse:6.49670
# [51]	validation-rmse:6.49397
# [52]	validation-rmse:6.49168
# [53]	validation-rmse:6.48953
# [54]	validation-rmse:6.48787
# [55]	validation-rmse:6.48610
# [56]	validation-rmse:6.48468
# [57]	validation-rmse:6.48279
# [58]	validation-rmse:6.48068
# [59]	validation-rmse:6.47916
# [60]	validation-rmse:6.47787
# [61]	validation-rmse:6.47653
# [62]	validation-rmse:6.47531
# [63]	validation-rmse:6.47385
# [64]	validation-rmse:6.47208
# [65]	validation-rmse:6.47074
# [66]	validation-rmse:6.46951
# [67]	validation-rmse:6.46828
# [68]	validation-rmse:6.46737
# [69]	validation-rmse:6.46643
# [70]	validation-rmse:6.46531
# [71]	validation-rmse:6.46423
# [72]	validation-rmse:6.46349
# [73]	validation-rmse:6.46290
# [74]	validation-rmse:6.46221
# [75]	validation-rmse:6.46124
# [76]	validation-rmse:6.46012
# [77]	validation-rmse:6.45937
# [78]	validation-rmse:6.45802
# [79]	validation-rmse:6.45671
# [80]	validation-rmse:6.45599
# [81]	validation-rmse:6.45542
# [82]	validation-rmse:6.45480
# [83]	validation-rmse:6.45406
# [84]	validation-rmse:6.45317
# [85]	validation-rmse:6.45207
# [86]	validation-rmse:6.45132
# [87]	validation-rmse:6.45021
# [88]	validation-rmse:6.44945
# [89]	validation-rmse:6.44856
# [90]	validation-rmse:6.44774
# [91]	validation-rmse:6.44711
# [92]	validation-rmse:6.44644
# [93]	validation-rmse:6.44568
# [94]	validation-rmse:6.44466
# [95]	validation-rmse:6.44430
# [96]	validation-rmse:6.44386
# [97]	validation-rmse:6.44291
# [98]	validation-rmse:6.44231
# [99]	validation-rmse:6.44209
# [0]	validation-rmse:15.86960
# [1]	validation-rmse:12.35412
# [2]	validation-rmse:10.09813
# [3]	validation-rmse:8.70002
# [4]	validation-rmse:7.85964
# [5]	validation-rmse:7.36200
# [6]	validation-rmse:7.06511
# [7]	validation-rmse:6.88170
# [8]	validation-rmse:6.76588
# [9]	validation-rmse:6.69351
# [10]	validation-rmse:6.64506
# [11]	validation-rmse:6.60624
# [12]	validation-rmse:6.58374
# [13]	validation-rmse:6.56386
# [14]	validation-rmse:6.55036
# [15]	validation-rmse:6.54232
# ...
# [2]	validation-rmse:17.87777
# [3]	validation-rmse:16.93259
# [4]	validation-rmse:16.05932
# [5]	validation-rmse:15.25307
# [6]	validation-rmse:14.50917
# [7]	validation-rmse:13.82368
# [8]	validation-rmse:13.19263
# [9]	validation-rmse:12.61211
# [10]	validation-rmse:12.07947
# [11]	validation-rmse:11.59033
# [12]	validation-rmse:11.14160
# [13]	validation-rmse:10.73176
# [14]	validation-rmse:10.35702
# [15]	validation-rmse:10.01539
# [16]	validation-rmse:9.70385
# [17]	validation-rmse:9.42138
# [18]	validation-rmse:9.16447
# [19]	validation-rmse:8.93086
# [20]	validation-rmse:8.71931
# [21]	validation-rmse:8.52755
# [22]	validation-rmse:8.35381
# [23]	validation-rmse:8.19557
# [24]	validation-rmse:8.05290
# [25]	validation-rmse:7.92354
# [26]	validation-rmse:7.80680
# [27]	validation-rmse:7.70042
# [28]	validation-rmse:7.60431
# [29]	validation-rmse:7.51795
# [30]	validation-rmse:7.43955
# [31]	validation-rmse:7.36886
# [32]	validation-rmse:7.30478
# [33]	validation-rmse:7.24671
# [34]	validation-rmse:7.19410
# [35]	validation-rmse:7.14549
# [36]	validation-rmse:7.10184
# [37]	validation-rmse:7.06239
# [38]	validation-rmse:7.02663
# [39]	validation-rmse:6.99401
# [40]	validation-rmse:6.96431
# [41]	validation-rmse:6.93694
# [42]	validation-rmse:6.91185
# [43]	validation-rmse:6.88917
# [44]	validation-rmse:6.86821
# [45]	validation-rmse:6.84915
# [46]	validation-rmse:6.83166
# [47]	validation-rmse:6.81563
# [48]	validation-rmse:6.80130
# [49]	validation-rmse:6.78791
# [50]	validation-rmse:6.77572
# [51]	validation-rmse:6.76472
# [52]	validation-rmse:6.75436
# [53]	validation-rmse:6.74419
# [54]	validation-rmse:6.73494
# [55]	validation-rmse:6.72603
# [56]	validation-rmse:6.71801
# [57]	validation-rmse:6.71033
# [58]	validation-rmse:6.70317
# [59]	validation-rmse:6.69671
# [60]	validation-rmse:6.69036
# [61]	validation-rmse:6.68485
# [62]	validation-rmse:6.67956
# [63]	validation-rmse:6.67488
# [64]	validation-rmse:6.67003
# [65]	validation-rmse:6.66595
# [66]	validation-rmse:6.66175
# [67]	validation-rmse:6.65809
# [68]	validation-rmse:6.65479
# [69]	validation-rmse:6.65152
# [70]	validation-rmse:6.64830
# [71]	validation-rmse:6.64529
# [72]	validation-rmse:6.64238
# [73]	validation-rmse:6.63984
# [74]	validation-rmse:6.63719
# [75]	validation-rmse:6.63492
# [76]	validation-rmse:6.63289
# [77]	validation-rmse:6.63090
# [78]	validation-rmse:6.62892
# [79]	validation-rmse:6.62707
# [80]	validation-rmse:6.62524
# [81]	validation-rmse:6.62370
# [82]	validation-rmse:6.62207
# [83]	validation-rmse:6.62053
# [84]	validation-rmse:6.61918
# [85]	validation-rmse:6.61798
# [86]	validation-rmse:6.61674
# [87]	validation-rmse:6.61559
# [88]	validation-rmse:6.61470
# [89]	validation-rmse:6.61390
# [90]	validation-rmse:6.61289
# [91]	validation-rmse:6.61202
# [92]	validation-rmse:6.61145
# [93]	validation-rmse:6.61061
# [94]	validation-rmse:6.60969
# [95]	validation-rmse:6.60891
# [96]	validation-rmse:6.60822
# [97]	validation-rmse:6.60777
# [98]	validation-rmse:6.60706
# [99]	validation-rmse:6.60629
# [0]	validation-rmse:17.77617
# [1]	validation-rmse:15.08876
# [2]	validation-rmse:12.99490
# [3]	validation-rmse:11.38056
# [4]	validation-rmse:10.15280
# [5]	validation-rmse:9.22772
# [6]	validation-rmse:8.53938
# [7]	validation-rmse:8.03257
# [8]	validation-rmse:7.66209
# [9]	validation-rmse:7.38920
# [10]	validation-rmse:7.18754
# [11]	validation-rmse:7.03980
# [12]	validation-rmse:6.92797
# [13]	validation-rmse:6.84457
# [14]	validation-rmse:6.77966
# [15]	validation-rmse:6.73135
# [16]	validation-rmse:6.69372
# [17]	validation-rmse:6.66530
# [18]	validation-rmse:6.64213
# [19]	validation-rmse:6.62450
# [20]	validation-rmse:6.60838
# [21]	validation-rmse:6.59651
# [22]	validation-rmse:6.58595
# [23]	validation-rmse:6.57731
# [24]	validation-rmse:6.56885
# [25]	validation-rmse:6.56222
# [26]	validation-rmse:6.55682
# [27]	validation-rmse:6.55237
# [28]	validation-rmse:6.54960
# [29]	validation-rmse:6.54434
# [30]	validation-rmse:6.54144
# [31]	validation-rmse:6.53904
# [32]	validation-rmse:6.53701
# [33]	validation-rmse:6.53519
# [34]	validation-rmse:6.53381
# [35]	validation-rmse:6.53221
# [36]	validation-rmse:6.53071
# [37]	validation-rmse:6.52966
# [38]	validation-rmse:6.52741
# [39]	validation-rmse:6.52658
# [40]	validation-rmse:6.52504
# [41]	validation-rmse:6.52446
# [42]	validation-rmse:6.52290
# [43]	validation-rmse:6.52124
# [44]	validation-rmse:6.52059
# [45]	validation-rmse:6.51978
# [46]	validation-rmse:6.51933
# [47]	validation-rmse:6.51852
# [48]	validation-rmse:6.51741
# [49]	validation-rmse:6.51666
# [50]	validation-rmse:6.51625
# [51]	validation-rmse:6.51525
# [52]	validation-rmse:6.51477
# [53]	validation-rmse:6.51397
# [54]	validation-rmse:6.51283
# [55]	validation-rmse:6.51202
# [56]	validation-rmse:6.51115
# [57]	validation-rmse:6.51071
# [58]	validation-rmse:6.51019
# [59]	validation-rmse:6.50973
# [60]	validation-rmse:6.50907
# [61]	validation-rmse:6.50876
# [62]	validation-rmse:6.50806
# [63]	validation-rmse:6.50742
# [64]	validation-rmse:6.50723
# [65]	validation-rmse:6.50698
# [66]	validation-rmse:6.50659
# [67]	validation-rmse:6.50611
# [68]	validation-rmse:6.50569
# [69]	validation-rmse:6.50523
# [70]	validation-rmse:6.50433
# [71]	validation-rmse:6.50426
# [72]	validation-rmse:6.50403
# [73]	validation-rmse:6.50342
# [74]	validation-rmse:6.50294
# [75]	validation-rmse:6.50234
# [76]	validation-rmse:6.50150
# [77]	validation-rmse:6.50059
# [78]	validation-rmse:6.50047
# [79]	validation-rmse:6.50019
# [80]	validation-rmse:6.49977
# [81]	validation-rmse:6.49967
# [82]	validation-rmse:6.49941
# [83]	validation-rmse:6.49871
# [84]	validation-rmse:6.49832
# [85]	validation-rmse:6.49815
# [86]	validation-rmse:6.49798
# [87]	validation-rmse:6.49756
# [88]	validation-rmse:6.49737
# [89]	validation-rmse:6.49722
# [90]	validation-rmse:6.49702
# [91]	validation-rmse:6.49695
# [92]	validation-rmse:6.49661
# [93]	validation-rmse:6.49639
# [94]	validation-rmse:6.49618
# [95]	validation-rmse:6.49608
# [96]	validation-rmse:6.49578
# [97]	validation-rmse:6.49549
# [98]	validation-rmse:6.49528
# [99]	validation-rmse:6.49524
# 100%|██████████| 10/10 [05:25<00:00, 32.58s/trial, best loss: 6.428035134808645]

# %%
mlflow.xgboost.autolog(disable=True)

# %%
with mlflow.start_run():
    
    train = xgb.DMatrix(X_train, label=y_train)
    valid = xgb.DMatrix(X_val, label=y_val)

    best_params = {
        'learning_rate': 0.09585355369315604,
        'max_depth': 30,
        'min_child_weight': 1.060597050922164,
        'objective': 'reg:squarederror',
        'reg_alpha': 0.018060244040060163,
        'reg_lambda': 0.011658731377413597,
        'seed': 42
    }

    mlflow.xgboost.autolog()

    mlflow.log_params(best_params)

    booster = xgb.train(
        params=best_params,
        dtrain=train,
        num_boost_round=30,
        evals=[(valid, 'validation')],
        early_stopping_rounds=15
    )

    y_pred = booster.predict(valid)
    rmse = mean_squared_error(y_val, y_pred, squared=False)
    mlflow.log_metric("rmse", rmse)

    with open("models/preprocessor.b", "wb") as f_out:
        pickle.dump(dv, f_out)
    mlflow.log_artifact("models/preprocessor.b", artifact_path="preprocessor")

    mlflow.xgboost.log_model(booster, artifact_path="models_mlflow")
# Out:
# [0]	validation-rmse:19.48425
# [1]	validation-rmse:17.95634
# [2]	validation-rmse:16.59114
# [3]	validation-rmse:15.37412
# [4]	validation-rmse:14.29011
# [5]	validation-rmse:13.32800
# [6]	validation-rmse:12.47570
# [7]	validation-rmse:11.72140
# [8]	validation-rmse:11.05888
# [9]	validation-rmse:10.47583
# [10]	validation-rmse:9.96483
# [11]	validation-rmse:9.51784
# [12]	validation-rmse:9.12620
# [13]	validation-rmse:8.78522
# [14]	validation-rmse:8.49037
# [15]	validation-rmse:8.23332
# [16]	validation-rmse:8.01179
# [17]	validation-rmse:7.81822
# [18]	validation-rmse:7.65209
# [19]	validation-rmse:7.50743
# [20]	validation-rmse:7.38235
# [21]	validation-rmse:7.27382
# [22]	validation-rmse:7.17865
# [23]	validation-rmse:7.09606
# [24]	validation-rmse:7.02481
# [25]	validation-rmse:6.96336
# [26]	validation-rmse:6.91001
# [27]	validation-rmse:6.86273
# [28]	validation-rmse:6.82111
# [29]	validation-rmse:6.78450
# [30]	validation-rmse:6.75253
# [31]	validation-rmse:6.72379
# [32]	validation-rmse:6.69828
# [33]	validation-rmse:6.67533
# [34]	validation-rmse:6.65594
# [35]	validation-rmse:6.63823
# [36]	validation-rmse:6.62237
# [37]	validation-rmse:6.60869
# [38]	validation-rmse:6.59673
# [39]	validation-rmse:6.58612
# [40]	validation-rmse:6.57635
# [41]	validation-rmse:6.56725
# [42]	validation-rmse:6.55951
# [43]	validation-rmse:6.55213
# [44]	validation-rmse:6.54590
# [45]	validation-rmse:6.53959
# [46]	validation-rmse:6.53464
# [47]	validation-rmse:6.53019
# [48]	validation-rmse:6.52650
# [49]	validation-rmse:6.52243
# [50]	validation-rmse:6.51983
# [51]	validation-rmse:6.51696
# [52]	validation-rmse:6.51425
# [53]	validation-rmse:6.51218
# [54]	validation-rmse:6.50939
# [55]	validation-rmse:6.50728
# [56]	validation-rmse:6.50533
# [57]	validation-rmse:6.50282
# [58]	validation-rmse:6.50099
# [59]	validation-rmse:6.49892
# [60]	validation-rmse:6.49719
# [61]	validation-rmse:6.49492
# [62]	validation-rmse:6.49347
# [63]	validation-rmse:6.49178
# [64]	validation-rmse:6.49026
# [65]	validation-rmse:6.48871
# [66]	validation-rmse:6.48779
# [67]	validation-rmse:6.48643
# [68]	validation-rmse:6.48508
# [69]	validation-rmse:6.48346
# [70]	validation-rmse:6.48224
# [71]	validation-rmse:6.48140
# [72]	validation-rmse:6.48045
# [73]	validation-rmse:6.47899
# [74]	validation-rmse:6.47849
# [75]	validation-rmse:6.47771
# [76]	validation-rmse:6.47630
# [77]	validation-rmse:6.47578
# [78]	validation-rmse:6.47497
# [79]	validation-rmse:6.47406
# [80]	validation-rmse:6.47340
# [81]	validation-rmse:6.47235
# [82]	validation-rmse:6.47127
# [83]	validation-rmse:6.47046
# [84]	validation-rmse:6.46950
# [85]	validation-rmse:6.46858
# [86]	validation-rmse:6.46750
# [87]	validation-rmse:6.46680
# [88]	validation-rmse:6.46649
# [89]	validation-rmse:6.46569
# [90]	validation-rmse:6.46511
# [91]	validation-rmse:6.46452
# [92]	validation-rmse:6.46346
# [93]	validation-rmse:6.46263
# [94]	validation-rmse:6.46173
# [95]	validation-rmse:6.46134
# [96]	validation-rmse:6.46066
# [97]	validation-rmse:6.46005
# [98]	validation-rmse:6.45936
# [99]	validation-rmse:6.45918
# 2023/05/25 23:32:38 WARNING mlflow.xgboost: Failed to infer model signature: could not sample data to infer model signature: please ensure that autologging is enabled before constructing the dataset.

# %%
## second way to see the models logs
with mlflow.start_run():
    
    train = xgb.DMatrix(X_train, label=y_train)
    valid = xgb.DMatrix(X_val, label=y_val)

    best_params = {
        'learning_rate': 0.09585355369315604,
        'max_depth': 30,
        'min_child_weight': 1.060597050922164,
        'objective': 'reg:squarederror',
        'reg_alpha': 0.018060244040060163,
        'reg_lambda': 0.011658731377413597,
        'seed': 42
    }

    mlflow.xgboost.autolog(disable=True)

    mlflow.log_params(best_params)

    booster = xgb.train(
        params=best_params,
        dtrain=train,
        num_boost_round=30,
        evals=[(valid, 'validation')],
        early_stopping_rounds=15
    )

    y_pred = booster.predict(valid)
    rmse = mean_squared_error(y_val, y_pred, squared=False)
    mlflow.log_metric("rmse", rmse)

    with open("models/preprocessor.b", "wb") as f_out:
        pickle.dump(dv, f_out)
    mlflow.log_artifact("models/preprocessor.b", artifact_path="preprocessor")
    mlflow.xgboost.log_model(booster, artifact_path="models_mlflow")
# Out:
# [0]	validation-rmse:19.48425
# [1]	validation-rmse:17.95634
# [2]	validation-rmse:16.59114
# [3]	validation-rmse:15.37412
# [4]	validation-rmse:14.29011
# [5]	validation-rmse:13.32800
# [6]	validation-rmse:12.47570
# [7]	validation-rmse:11.72140
# [8]	validation-rmse:11.05888
# [9]	validation-rmse:10.47583
# [10]	validation-rmse:9.96483
# [11]	validation-rmse:9.51784
# [12]	validation-rmse:9.12620
# [13]	validation-rmse:8.78522
# [14]	validation-rmse:8.49037
# [15]	validation-rmse:8.23332
# [16]	validation-rmse:8.01179
# [17]	validation-rmse:7.81822
# [18]	validation-rmse:7.65209
# [19]	validation-rmse:7.50743
# [20]	validation-rmse:7.38235
# [21]	validation-rmse:7.27382
# [22]	validation-rmse:7.17865
# [23]	validation-rmse:7.09606
# [24]	validation-rmse:7.02481
# [25]	validation-rmse:6.96336
# [26]	validation-rmse:6.91001
# [27]	validation-rmse:6.86273
# [28]	validation-rmse:6.82111
# [29]	validation-rmse:6.78450

# %%
## predictiong from the ast example
logged_model = 'runs:/3129d4b25576436592995adb52a67781/models_mlflow'

# Load model as a PyFuncModel.
loaded_model = mlflow.pyfunc.load_model(logged_model)

# %%
# Predict on a Pandas DataFrame.
loaded_model
# Out:
# mlflow.pyfunc.loaded_model:
#   artifact_path: models_mlflow
#   flavor: mlflow.xgboost
#   run_id: 3129d4b25576436592995adb52a67781

# %%
xgboost_model = mlflow.xgboost.load_model(logged_model)

# %%
xgboost_model

# %%
y_pred = xgboost_model.predict(valid)

# %% [markdown]
# Logging models in MLflow using this two options
# * log model as an artifact
#     ```mlflow.log_artifact("mymodel", artifact_path="models/")```
# * Log model using the method  log_model
#     ```mlflow.<framework>.log_model(mymodel, artifact_path="models/")```

# %% [markdown]
# ## Model registry

# %%
from tqdm import tqdm

# %%
from sklearn.ensemble import RandomForestRegressor, GradientBoostingRegressor, ExtraTreesRegressor
from sklearn.svm import LinearSVR

mlflow.sklearn.autolog()

algorithms = {'RFR': RandomForestRegressor, 'GBR': GradientBoostingRegressor,
              'ETR': ExtraTreesRegressor, 'LSVR': LinearSVR}

for model_name, model_class in tqdm(algorithms.items()):
    
    with mlflow.start_run():
        
        mlflow.set_tag("developer", "luis")

        mlflow.log_param("train-data-path", "./data/green_tripdata_2021-01.csv")
        mlflow.log_param("valid-data-path", "./data/green_tripdata_2021-02.csv")
        mlflow.log_artifact("models/preprocessor.b", artifact_path="preprocessor")
        
        if model_name in ('RFR', 'ETR'):
            mlmodel = model_class(n_jobs=-1)
        else:
            mlmodel = model_class()

        mlmodel.fit(X_train, y_train)

        y_pred = mlmodel.predict(X_val)
        rmse = mean_squared_error(y_val, y_pred, squared=False)
        mlflow.log_metric("rmse", rmse)
# Out:
#  75%|███████▌  | 3/4 [14:15<05:30, 330.29s/it]/home/juanxo90/anaconda3/envs/ml_nlp/lib/python3.7/site-packages/sklearn/svm/_base.py:1208: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   ConvergenceWarning,
# 100%|██████████| 4/4 [14:25<00:00, 216.44s/it]
